# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv ("practice_dataset.csv")

# %%
print(df.head())
# Out:
#    Order_ID   Product     Category    City  Sales  Quantity  Rating  \
# 0      1001    Laptop  Electronics  Jaipur  55000         5     4.5
# 1      1002     Mouse  Accessories   Delhi   2500        10     4.0
# 2      1003  Keyboard  Accessories  Mumbai   4500         8     3.8
# 3      1004  Notebook        Books    Pune   1800        15     4.2
# 4      1005   Monitor  Electronics  Jaipur  32000         4     4.7
#
#   Payment_Mode
# 0          UPI
# 1         Cash
# 2         Card
# 3          UPI
# 4         Card

# %%
print(df.shape)
# Out:
# (50, 8)

# %%
print(df.size)
# Out:
# 400

# %%
print(df.tail())
# Out:
#     Order_ID    Product     Category    City  Sales  Quantity  Rating  \
# 45      1046  Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 46      1047   Keyboard  Accessories   Delhi   4800         7     4.2
# 47      1048    Monitor  Electronics  Mumbai  29000         4     4.7
# 48      1049   Notebook        Books    Pune   2000        12     4.0
# 49      1050     Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 45         Card
# 46         Cash
# 47          UPI
# 48         Card
# 49         Cash

# %%
print(df.sample(10))
# Out:
#     Order_ID    Product     Category     City  Sales  Quantity  Rating  \
# 22      1023    Printer  Electronics   Jaipur  21000         3     3.8
# 3       1004   Notebook        Books     Pune   1800        15     4.2
# 47      1048    Monitor  Electronics   Mumbai  29000         4     4.7
# 7       1008    Printer  Electronics  Kolkata  22000         3     3.9
# 24      1025        Pen  Accessories     Pune   1200        15     3.5
# 48      1049   Notebook        Books     Pune   2000        12     4.0
# 9       1010  Pen Drive  Accessories   Jaipur   4000         9     3.7
# 17      1018   Keyboard  Accessories   Jaipur   5000         8     4.0
# 49      1050     Laptop  Electronics   Jaipur  68000         6     4.9
# 30      1031   Keyboard  Accessories   Jaipur   5200         8     4.0
#
#    Payment_Mode
# 22         Cash
# 3           UPI
# 47          UPI
# 7          Card
# 24         Card
# 48         Card
# 9          Cash
# 17          UPI
# 49         Cash
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      50 non-null     int64
#  1   Product       50 non-null     object
#  2   Category      50 non-null     object
#  3   City          50 non-null     object
#  4   Sales         50 non-null     int64
#  5   Quantity      50 non-null     int64
#  6   Rating        50 non-null     float64
#  7   Payment_Mode  50 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.3+ KB
# None

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv ("practice_dataset.csv")

# %%
data = (df.head())
print(data)
# Out:
#    Order_ID   Product     Category    City  Sales  Quantity  Rating  \
# 0      1001    Laptop  Electronics  Jaipur  55000         5     4.5
# 1      1002     Mouse  Accessories   Delhi   2500        10     4.0
# 2      1003  Keyboard  Accessories  Mumbai   4500         8     3.8
# 3      1004  Notebook        Books    Pune   1800        15     4.2
# 4      1005   Monitor  Electronics  Jaipur  32000         4     4.7
#
#   Payment_Mode
# 0          UPI
# 1         Cash
# 2         Card
# 3          UPI
# 4         Card

# %%
print(df.tail())
# Out:
#     Order_ID    Product     Category    City  Sales  Quantity  Rating  \
# 45      1046  Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 46      1047   Keyboard  Accessories   Delhi   4800         7     4.2
# 47      1048    Monitor  Electronics  Mumbai  29000         4     4.7
# 48      1049   Notebook        Books    Pune   2000        12     4.0
# 49      1050     Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 45         Card
# 46         Cash
# 47          UPI
# 48         Card
# 49         Cash

# %%
data = (df.sample(10))
print(data)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 39      1040   Pen Drive  Accessories  Kolkata   3500        10     3.7
# 48      1049    Notebook        Books     Pune   2000        12     4.0
# 45      1046   Mouse Pad  Accessories   Jaipur   3000        11     3.9
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 24      1025         Pen  Accessories     Pune   1200        15     3.5
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
#
#    Payment_Mode
# 39         Card
# 48         Card
# 45         Card
# 36         Card
# 32          UPI
# 10         Card
# 24         Card
# 6           UPI
# 5          Cash
# ...

# %%
row_cols = (df.shape)
print(row_cols)
# Out:
# (50, 8)

# %%
print (df.size)
# Out:
# 400

# %%
print (df.columns)
# Out:
# Index(['Order_ID', 'Product', 'Category', 'City', 'Sales', 'Quantity',
#        'Rating', 'Payment_Mode'],
#       dtype='object')

# %%
print (df.dtypes)
# Out:
# Order_ID          int64
# Product          object
# Category         object
# City             object
# Sales             int64
# Quantity          int64
# Rating          float64
# Payment_Mode     object
# dtype: object

# %%
information = (df.info())
print(information)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      50 non-null     int64
#  1   Product       50 non-null     object
#  2   Category      50 non-null     object
#  3   City          50 non-null     object
#  4   Sales         50 non-null     int64
#  5   Quantity      50 non-null     int64
#  6   Rating        50 non-null     float64
#  7   Payment_Mode  50 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.3+ KB
# None

# %%
print (df.describe())
# Out:
#          Order_ID         Sales   Quantity     Rating
# count    50.00000     50.000000  50.000000  50.000000
# mean   1025.50000  15410.000000   6.980000   4.214000
# std      14.57738  16161.976667   3.191123   0.347005
# min    1001.00000   1200.000000   3.000000   3.500000
# 25%    1013.25000   4000.000000   5.000000   4.000000
# 50%    1025.50000   9250.000000   6.000000   4.150000
# 75%    1037.75000  21750.000000   8.750000   4.500000
# max    1050.00000  68000.000000  15.000000   4.900000

# %%
print (df.empty)
# Out:
# False

# %%
orders = df [df ['Sales']>10000 ]
print(orders)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 28      1029       Chair    Furniture  Kolkata  14500         4     3.9
# ...

# %%
print (df [df ['City'] == 'Jaipur' ])
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 17      1018    Keyboard  Accessories  Jaipur   5000         8     4.0
# 22      1023     Printer  Electronics  Jaipur  21000         3     3.8
# 26      1027        Book        Books  Jaipur   3200        10     4.3
# 30      1031    Keyboard  Accessories  Jaipur   5200         8     4.0
# 35      1036  Book Stand        Books  Jaipur   5500         9     4.1
# 42      1043      Webcam  Electronics  Jaipur  12500         5     4.3
# 45      1046   Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# ...

# %%
print (df [df ["Rating"] >=4.5 ])
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 13      1014    Chair    Furniture   Jaipur  15000         3     4.5
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028   Webcam  Electronics    Delhi  11000         6     4.5
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# 43      1044    Chair    Furniture     Pune  16000         3     4.5
# ...

# %%
electronics = df [ df ["Category"] == "Electronics" ]
print (electronics)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# ...

# %%
sales = df [ ( df ['Sales'] > 10000 ) & ( df [ 'Rating'] > 4  ) ]
print(sales)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# ...

# %%
print ( df [ ( df ['Sales'] > 20000 ) & ( df ['Quantity'] >= 5 ) ] )
# Out:
#     Order_ID Product     Category    City  Sales  Quantity  Rating  \
# 0       1001  Laptop  Electronics  Jaipur  55000         5     4.5
# 8       1009  Tablet  Electronics    Pune  28000         5     4.6
# 18      1019  Laptop  Electronics   Delhi  48000         6     4.8
# 23      1024  Tablet  Electronics   Delhi  26000         5     4.6
# 32      1033  Laptop  Electronics  Mumbai  60000         5     4.9
# 38      1039  Tablet  Electronics    Pune  24000         7     4.6
# 49      1050  Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 8           UPI
# 18         Card
# 23          UPI
# 32          UPI
# 38          UPI
# 49         Cash

# %%
print ( df [ ( df ['Category'] == 'Electronics' ) & ( df ['Sales'] > 15000 ) ] )
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008  Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 22      1023  Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037  Printer  Electronics    Delhi  19500         3     3.9
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# ...

# %%
data = df.query ( "Category == 'Electronics' and Sales > 15000" )
print(data)
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008  Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 22      1023  Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037  Printer  Electronics    Delhi  19500         3     3.9
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("practice_dataset.csv")

# %%
city = df [ ( df ["City"] == "Jaipur" ) & ( df ["Rating"] >= 4.5 ) ] 
print(city)
# Out:
#     Order_ID  Product     Category    City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics  Jaipur  32000         4     4.7
# 13      1014    Chair    Furniture  Jaipur  15000         3     4.5
# 49      1050   Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 13         Card
# 49         Cash

# %%
print ( df  [ ( df ["Category"] == "Electronics" ) | ( df ["Category"] == "Books" ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# ...

# %%
print ( df [ ( df ["City"] == "Jaipur" ) | ( df ["City"] == "Delhi" ) ] )
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories   Delhi   2500        10     4.0
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books   Delhi   6500         6     4.1
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture   Delhi  12000         4     3.8
# 17      1018    Keyboard  Accessories  Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 22      1023     Printer  Electronics  Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics   Delhi  26000         5     4.6
# ...

# %%
payment = df [ ( df ["Payment_Mode"] == "UPI" ) | ( df ["Payment_Mode"] == "Card" ) ]
print(payment)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# ...

# %%
df_1 = df [ ( df ["Category"] == "Books" ) | ( df ["Category"] == "Furniture" ) ] 
print (df_1)
# Out:
#     Order_ID     Product   Category     City  Sales  Quantity  Rating  \
# 3       1004    Notebook      Books     Pune   1800        15     4.2
# 5       1006  Book Stand      Books    Delhi   6500         6     4.1
# 11      1012        Book      Books   Mumbai   3500        12     4.0
# 13      1014       Chair  Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk  Furniture    Delhi  12000         4     3.8
# 15      1016    Notebook      Books  Kolkata   2500         5     4.1
# 20      1021  Book Shelf      Books   Mumbai   7000         7     4.2
# 26      1027        Book      Books   Jaipur   3200        10     4.3
# 28      1029       Chair  Furniture  Kolkata  14500         4     3.9
# 29      1030        Desk  Furniture     Pune  13000         5     4.1
# 33      1034    Notebook      Books     Pune   2200        14     4.2
# 35      1036  Book Stand      Books   Jaipur   5500         9     4.1
# ...

# %%
orders = df [ df ["City"].isin ( ["Jaipur" ,"Delhi" ,"Mumbai" ] ) ]
print (orders)
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories   Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories  Mumbai   4500         8     3.8
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books   Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics  Mumbai   8500         7     4.3
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 11      1012        Book        Books  Mumbai   3500        12     4.0
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture   Delhi  12000         4     3.8
# 16      1017   Mouse Pad  Accessories  Mumbai   1800        10     3.9
# ...

# %%
print ( df [ df ["Category"] .isin ( ["Electronics" , "Books" , "Accessories" ] ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# ...

# %%
print ( df [ df ["Payment_Mode"] .isin ( ["UPI" , "Card"] ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# ...

# %%
city = df [ df ["City"] .isin ( ["Pune" , "Kolkata" , "Jaipur" ] ) ]
print(city)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# ...

# %%
print ( df [ df ["Sales"] .between ( 5000 , 20000 ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 25      1026  Laptop Bag  Accessories   Mumbai   6500         8     4.0
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 28      1029       Chair    Furniture  Kolkata  14500         4     3.9
# ...

# %%
q = df [ df ["Quantity"] .between ( 5 , 10 ) ]
print (q)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# ...

# %%
print ( df [ df ["Rating"] .between (4.0 , 4.5 ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# ...

# %%
print ( df [ df ["Sales"] .between ( 10000 , 30000 ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 28      1029       Chair    Furniture  Kolkata  14500         4     3.9
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv ("practice_dataset.csv")

# %%
data = df [ df ["Product"] .str.contains ("Book" , na = False ) ]
print(data)
# Out:
#     Order_ID     Product Category    City  Sales  Quantity  Rating  \
# 5       1006  Book Stand    Books   Delhi   6500         6     4.1
# 11      1012        Book    Books  Mumbai   3500        12     4.0
# 20      1021  Book Shelf    Books  Mumbai   7000         7     4.2
# 26      1027        Book    Books  Jaipur   3200        10     4.3
# 35      1036  Book Stand    Books  Jaipur   5500         9     4.1
# 41      1042        Book    Books  Mumbai   4000         8     4.0
#
#    Payment_Mode
# 5          Cash
# 11          UPI
# 20          UPI
# 26          UPI
# 35          UPI
# 41          UPI

# %%
print ( df [ df ["Product"] .str.contains ("Laptop" , case = False , na = False) ] )
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 25      1026  Laptop Bag  Accessories  Mumbai   6500         8     4.0
# 32      1033      Laptop  Electronics  Mumbai  60000         5     4.9
# 40      1041      Laptop  Electronics   Delhi  45000         4     4.8
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 10         Card
# 18         Card
# 25         Cash
# 32          UPI
# 40         Cash
# 49         Cash

# %%
print ( df [ df ["Product"] .str.contains ("mouse" , case = False , na = False ) ] )
# Out:
#     Order_ID    Product     Category    City  Sales  Quantity  Rating  \
# 1       1002      Mouse  Accessories   Delhi   2500        10     4.0
# 16      1017  Mouse Pad  Accessories  Mumbai   1800        10     3.9
# 31      1032      Mouse  Accessories   Delhi   2800        12     3.8
# 45      1046  Mouse Pad  Accessories  Jaipur   3000        11     3.9
#
#    Payment_Mode
# 1          Cash
# 16         Card
# 31         Cash
# 45         Card

# %%
print ( df [ df ["Product"] .str.contains ("Pen" , case = False , na = False ) ] )
# Out:
#     Order_ID    Product     Category     City  Sales  Quantity  Rating  \
# 9       1010  Pen Drive  Accessories   Jaipur   4000         9     3.7
# 24      1025        Pen  Accessories     Pune   1200        15     3.5
# 39      1040  Pen Drive  Accessories  Kolkata   3500        10     3.7
#
#    Payment_Mode
# 9          Cash
# 24         Card
# 39         Card

# %%
f = df.query ("Sales > 10000 and Rating >= 4")
print(f)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# ...

# %%
print ( df.query ("Quantity >= 5 and Sales > 15000" ) )
# Out:
#     Order_ID Product     Category    City  Sales  Quantity  Rating  \
# 0       1001  Laptop  Electronics  Jaipur  55000         5     4.5
# 8       1009  Tablet  Electronics    Pune  28000         5     4.6
# 18      1019  Laptop  Electronics   Delhi  48000         6     4.8
# 23      1024  Tablet  Electronics   Delhi  26000         5     4.6
# 32      1033  Laptop  Electronics  Mumbai  60000         5     4.9
# 38      1039  Tablet  Electronics    Pune  24000         7     4.6
# 49      1050  Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 8           UPI
# 18         Card
# 23          UPI
# 32          UPI
# 38          UPI
# 49         Cash

# %%
print ( df.query ("Rating >= 4.5 and Sales > 20000 " ) )
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# 47      1048  Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050   Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 8           UPI
# ...

# %%
print ( df.query ("Quantity > 5 and Rating >= 4.2 " ) )
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 3       1004    Notebook        Books    Pune   1800        15     4.2
# 6       1007  Headphones  Electronics  Mumbai   8500         7     4.3
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 12      1013      Webcam  Electronics    Pune   9500         7     4.4
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 20      1021  Book Shelf        Books  Mumbai   7000         7     4.2
# 26      1027        Book        Books  Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics   Delhi  11000         6     4.5
# 33      1034    Notebook        Books    Pune   2200        14     4.2
# 38      1039      Tablet  Electronics    Pune  24000         7     4.6
# 46      1047    Keyboard  Accessories   Delhi   4800         7     4.2
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 3           UPI
# ...

# %%
data =  df.query("(City == 'Jaipur' or City == 'Delhi' ) and Sales > 10000" ) 
print (data)
# Out:
#     Order_ID  Product     Category    City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics  Jaipur  32000         4     4.7
# 13      1014    Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015     Desk    Furniture   Delhi  12000         4     3.8
# 18      1019   Laptop  Electronics   Delhi  48000         6     4.8
# 22      1023  Printer  Electronics  Jaipur  21000         3     3.8
# 23      1024   Tablet  Electronics   Delhi  26000         5     4.6
# 27      1028   Webcam  Electronics   Delhi  11000         6     4.5
# 36      1037  Printer  Electronics   Delhi  19500         3     3.9
# 40      1041   Laptop  Electronics   Delhi  45000         4     4.8
# 42      1043   Webcam  Electronics  Jaipur  12500         5     4.3
# 49      1050   Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 13         Card
# ...

# %%
print ( df.query ("(City =='Jaipur' or City == 'Delhi' ) and   Sales > 10000" ) )
# Out:
#     Order_ID  Product     Category    City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics  Jaipur  32000         4     4.7
# 13      1014    Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015     Desk    Furniture   Delhi  12000         4     3.8
# 18      1019   Laptop  Electronics   Delhi  48000         6     4.8
# 22      1023  Printer  Electronics  Jaipur  21000         3     3.8
# 23      1024   Tablet  Electronics   Delhi  26000         5     4.6
# 27      1028   Webcam  Electronics   Delhi  11000         6     4.5
# 36      1037  Printer  Electronics   Delhi  19500         3     3.9
# 40      1041   Laptop  Electronics   Delhi  45000         4     4.8
# 42      1043   Webcam  Electronics  Jaipur  12500         5     4.3
# 49      1050   Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 13         Card
# ...

# %%
print ( df.query ( "(Category == 'Electronics' or Category == 'Books' ) and Rating >= 4 " ) )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# ...

# %%
print ( df [ df ["Sales"] .between ( 5000 , 20000 ) & ( df ["Quantity"] >= 5 ) ] )
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 25      1026  Laptop Bag  Accessories   Mumbai   6500         8     4.0
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 30      1031    Keyboard  Accessories   Jaipur   5200         8     4.0
# 35      1036  Book Stand        Books   Jaipur   5500         9     4.1
# ...

# %%
print ( df.query ( "(City == 'Mumbai' or City == 'Pune' ) and Sales > 10000 and Rating >= 4 ") )
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 8       1009      Tablet  Electronics    Pune  28000         5     4.6
# 19      1020     Monitor  Electronics    Pune  27000         4     4.5
# 29      1030        Desk    Furniture    Pune  13000         5     4.1
# 32      1033      Laptop  Electronics  Mumbai  60000         5     4.9
# 37      1038  Headphones  Electronics  Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics    Pune  24000         7     4.6
# 43      1044       Chair    Furniture    Pune  16000         3     4.5
# 47      1048     Monitor  Electronics  Mumbai  29000         4     4.7
#
#    Payment_Mode
# 8           UPI
# 19         Cash
# 29          UPI
# 32          UPI
# 37         Cash
# 38          UPI
# 43         Cash
# 47          UPI

# %%
print ( df [ df ["Sales"] > 20000 ] [ ['Product' , 'City' , 'Sales' ] ] )
# Out:
#     Product     City  Sales
# 0    Laptop   Jaipur  55000
# 4   Monitor   Jaipur  32000
# 7   Printer  Kolkata  22000
# 8    Tablet     Pune  28000
# 18   Laptop    Delhi  48000
# 19  Monitor     Pune  27000
# 22  Printer   Jaipur  21000
# 23   Tablet    Delhi  26000
# 32   Laptop   Mumbai  60000
# 34  Monitor  Kolkata  30000
# 38   Tablet     Pune  24000
# 40   Laptop    Delhi  45000
# 47  Monitor   Mumbai  29000
# 49   Laptop   Jaipur  68000

# %%
print ( df [ df ["Rating"] >= 4.5 ] [ ['Product' , 'Rating' ] ] )
# Out:
#     Product  Rating
# 0    Laptop     4.5
# 4   Monitor     4.7
# 8    Tablet     4.6
# 13    Chair     4.5
# 18   Laptop     4.8
# 19  Monitor     4.5
# 23   Tablet     4.6
# 27   Webcam     4.5
# 32   Laptop     4.9
# 34  Monitor     4.7
# 38   Tablet     4.6
# 40   Laptop     4.8
# 43    Chair     4.5
# 47  Monitor     4.7
# 49   Laptop     4.9

# %%
print ( df [ df ['City'] == 'Jaipur' ] [ ['Order_ID' , 'Product' , 'Sales' ] ] )
# Out:
#     Order_ID     Product  Sales
# 0       1001      Laptop  55000
# 4       1005     Monitor  32000
# 9       1010   Pen Drive   4000
# 13      1014       Chair  15000
# 17      1018    Keyboard   5000
# 22      1023     Printer  21000
# 26      1027        Book   3200
# 30      1031    Keyboard   5200
# 35      1036  Book Stand   5500
# 42      1043      Webcam  12500
# 45      1046   Mouse Pad   3000
# 49      1050      Laptop  68000

# %%
print ( df [ ( df ['Category'] == 'Electronics') | ( df ['Category'] == 'Books' ) ] [ ['Product','Category','Sales']])
# Out:
#        Product     Category  Sales
# 0       Laptop  Electronics  55000
# 3     Notebook        Books   1800
# 4      Monitor  Electronics  32000
# 5   Book Stand        Books   6500
# 6   Headphones  Electronics   8500
# 7      Printer  Electronics  22000
# 8       Tablet  Electronics  28000
# 11        Book        Books   3500
# 12      Webcam  Electronics   9500
# 15    Notebook        Books   2500
# 18      Laptop  Electronics  48000
# 19     Monitor  Electronics  27000
# 20  Book Shelf        Books   7000
# 21  Headphones  Electronics   9000
# 22     Printer  Electronics  21000
# 23      Tablet  Electronics  26000
# 26        Book        Books   3200
# 27      Webcam  Electronics  11000
# 32      Laptop  Electronics  60000
# 33    Notebook        Books   2200
# 34     Monitor  Electronics  30000
# 35  Book Stand        Books   5500
# 36     Printer  Electronics  19500
# 37  Headphones  Electronics  10500
# 38      Tablet  Electronics  24000
# 40      Laptop  Electronics  45000
# ...

# %%
print ( df [
     ( df ['Sales'] > 10000 ) &
    ( df['Rating'] >= 4.5 ) &
    ( df['City' ] == 'Jaipur' ) | ( df ['City'] == 'Delhi' ) ] )
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories   Delhi   2500        10     4.0
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books   Delhi   6500         6     4.1
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture   Delhi  12000         4     3.8
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 23      1024      Tablet  Electronics   Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics   Delhi  11000         6     4.5
# 31      1032       Mouse  Accessories   Delhi   2800        12     3.8
# 36      1037     Printer  Electronics   Delhi  19500         3     3.9
# ...
