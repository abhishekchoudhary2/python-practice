# %%
import pandas as pd

data = {
    "Order_ID": range(1001, 1051),

    "Customer": [
        "Amit", "Priya", "Rahul", "Neha", "Vikas",
        "Sneha", "Rohit", "Anjali", "Karan", "Pooja",
        "Amit", "Priya", "Rahul", "Neha", "Vikas",
        "Sneha", "Rohit", "Anjali", "Karan", "Pooja",
        "Amit", "Priya", "Rahul", "Neha", "Vikas",
        "Sneha", "Rohit", "Anjali", "Karan", "Pooja",
        "Amit", "Priya", "Rahul", "Neha", "Vikas",
        "Sneha", "Rohit", "Anjali", "Karan", "Pooja",
        "Amit", "Priya", "Rahul", "Neha", "Vikas",
        "Sneha", "Rohit", "Anjali", "Karan", "Pooja"
    ],

    "City": [
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai"
    ],

    "Category": [
        "Electronics", "Furniture", "Clothing", "Electronics", "Furniture",
        "Clothing", "Electronics", "Clothing", "Furniture", "Electronics",
        "Clothing", "Furniture", "Electronics", "Clothing", "Furniture",
        "Electronics", "Clothing", "Furniture", "Electronics", "Clothing",
        "Furniture", "Electronics", "Clothing", "Furniture", "Electronics",
        "Clothing", "Furniture", "Electronics", "Clothing", "Furniture",
        "Electronics", "Clothing", "Furniture", "Electronics", "Clothing",
        "Furniture", "Electronics", "Clothing", "Furniture", "Electronics",
        "Clothing", "Furniture", "Electronics", "Clothing", "Furniture",
        "Electronics", "Clothing", "Furniture", "Electronics", "Clothing"
    ],

    "Product": [
        "Laptop", "Chair", "T-Shirt", "Mobile", "Table",
        "Jeans", "Headphones", "Shoes", "Sofa", "Tablet",
        "Jacket", "Desk", "Laptop", "T-Shirt", "Chair",
        "Mobile", "Shoes", "Table", "Headphones", "Jeans",
        "Sofa", "Tablet", "Jacket", "Desk", "Laptop",
        "Shoes", "Chair", "Mobile", "T-Shirt", "Table",
        "Headphones", "Jeans", "Sofa", "Laptop", "Jacket",
        "Tablet", "Shoes", "Desk", "Mobile", "Chair",
        "T-Shirt", "Headphones", "Table", "Jeans", "Laptop",
        "Sofa", "Tablet", "Jacket", "Shoes", "Desk"
    ],

    "Quantity": [
        2, 1, 4, 2, 1,
        3, 2, 5, 1, 2,
        3, 2, 1, 4, 2,
        3, 5, 1, 2, 4,
        2, 3, 4, 1, 2,
        5, 2, 3, 4, 1,
        2, 3, 1, 4, 2,
        3, 5, 2, 1, 4,
        3, 2, 5, 1, 2,
        4, 3, 2, 5, 1
    ],

    "Sales": [
        1200, 800, 600, 1500, 900,
        700, 1100, 750, 1300, 1600,
        650, 1000, 1250, 700, 850,
        1400, 900, 1200, 1150, 800,
        1350, 1700, 650, 950, 1450,
        1000, 780, 1550, 720, 1100,
        1250, 850, 600, 1600, 900,
        950, 1400, 780, 1150, 1300,
        700, 1200, 1450, 820, 1050,
        1500, 900, 1350, 760, 1100
    ],

    "Profit": [
        200, 120, 150, 300, 180,
        140, 220, 160, 250, 320,
        130, 200, 250, 140, 170,
        280, 180, 240, 230, 160,
        270, 340, 130, 190, 290,
        200, 150, 310, 140, 220,
        250, 170, 120, 320, 180,
        190, 280, 150, 230, 260,
        140, 240, 290, 160, 210,
        300, 180, 270, 150, 220
    ],

    "Payment_Mode": [
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card"
    ],

    "Order_Status": [
        "Delivered", "Delivered", "Pending", "Delivered", "Cancelled",
        "Delivered", "Pending", "Delivered", "Cancelled", "Delivered",
        "Delivered", "Pending", "Delivered", "Cancelled", "Delivered",
        "Pending", "Delivered", "Delivered", "Cancelled", "Pending",
        "Delivered", "Delivered", "Cancelled", "Pending", "Delivered",
        "Delivered", "Pending", "Delivered", "Cancelled", "Delivered",
        "Pending", "Delivered", "Cancelled", "Delivered", "Delivered",
        "Pending", "Cancelled", "Delivered", "Pending", "Delivered",
        "Delivered", "Cancelled", "Pending", "Delivered", "Delivered",
        "Pending", "Cancelled", "Delivered", "Pending", "Delivered"
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Order_ID Customer    City     Category     Product  Quantity  Sales  \
# 0       1001     Amit   Delhi  Electronics      Laptop         2   1200
# 1       1002    Priya  Mumbai    Furniture       Chair         1    800
# 2       1003    Rahul  Jaipur     Clothing     T-Shirt         4    600
# 3       1004     Neha   Delhi  Electronics      Mobile         2   1500
# 4       1005    Vikas    Pune    Furniture       Table         1    900
# 5       1006    Sneha  Mumbai     Clothing       Jeans         3    700
# 6       1007    Rohit  Jaipur  Electronics  Headphones         2   1100
# 7       1008   Anjali   Delhi     Clothing       Shoes         5    750
# 8       1009    Karan    Pune    Furniture        Sofa         1   1300
# 9       1010    Pooja  Mumbai  Electronics      Tablet         2   1600
# 10      1011     Amit   Delhi     Clothing      Jacket         3    650
# 11      1012    Priya  Mumbai    Furniture        Desk         2   1000
# 12      1013    Rahul  Jaipur  Electronics      Laptop         1   1250
# 13      1014     Neha   Delhi     Clothing     T-Shirt         4    700
# 14      1015    Vikas    Pune    Furniture       Chair         2    850
# 15      1016    Sneha  Mumbai  Electronics      Mobile         3   1400
# 16      1017    Rohit  Jaipur     Clothing       Shoes         5    900
# 17      1018   Anjali   Delhi    Furniture       Table         1   1200
# 18      1019    Karan    Pune  Electronics  Headphones         2   1150
# 19      1020    Pooja  Mumbai     Clothing       Jeans         4    800
# 20      1021     Amit   Delhi    Furniture        Sofa         2   1350
# 21      1022    Priya  Mumbai  Electronics      Tablet         3   1700
# 22      1023    Rahul  Jaipur     Clothing      Jacket         4    650
# 23      1024     Neha   Delhi    Furniture        Desk         1    950
# 24      1025    Vikas    Pune  Electronics      Laptop         2   1450
# 25      1026    Sneha  Mumbai     Clothing       Shoes         5   1000
# 26      1027    Rohit  Jaipur    Furniture       Chair         2    780
# 27      1028   Anjali   Delhi  Electronics      Mobile         3   1550
# 28      1029    Karan    Pune     Clothing     T-Shirt         4    720
# 29      1030    Pooja  Mumbai    Furniture       Table         1   1100
# 30      1031     Amit   Delhi  Electronics  Headphones         2   1250
# 31      1032    Priya  Mumbai     Clothing       Jeans         3    850
# 32      1033    Rahul  Jaipur    Furniture        Sofa         1    600
# 33      1034     Neha   Delhi  Electronics      Laptop         4   1600
# 34      1035    Vikas    Pune     Clothing      Jacket         2    900
# 35      1036    Sneha  Mumbai    Furniture      Tablet         3    950
# 36      1037    Rohit  Jaipur  Electronics       Shoes         5   1400
# 37      1038   Anjali   Delhi     Clothing        Desk         2    780
# 38      1039    Karan    Pune    Furniture      Mobile         1   1150
# 39      1040    Pooja  Mumbai  Electronics       Chair         4   1300
# 40      1041     Amit   Delhi     Clothing     T-Shirt         3    700
# 41      1042    Priya  Mumbai    Furniture  Headphones         2   1200
# 42      1043    Rahul  Jaipur  Electronics       Table         5   1450
# 43      1044     Neha   Delhi     Clothing       Jeans         1    820
# 44      1045    Vikas    Pune    Furniture      Laptop         2   1050
# 45      1046    Sneha  Mumbai  Electronics        Sofa         4   1500
# 46      1047    Rohit  Jaipur     Clothing      Tablet         3    900
# 47      1048   Anjali   Delhi    Furniture      Jacket         2   1350
# 48      1049    Karan    Pune  Electronics       Shoes         5    760
# 49      1050    Pooja  Mumbai     Clothing        Desk         1   1100
#
#     Profit Payment_Mode Order_Status
# 0      200          UPI    Delivered
# 1      120         Card    Delivered
# 2      150         Cash      Pending
# 3      300          UPI    Delivered
# 4      180         Card    Cancelled
# 5      140         Cash    Delivered
# 6      220          UPI      Pending
# 7      160         Card    Delivered
# 8      250         Cash    Cancelled
# 9      320          UPI    Delivered
# 10     130         Card    Delivered
# 11     200         Cash      Pending
# 12     250          UPI    Delivered
# 13     140         Card    Cancelled
# 14     170         Cash    Delivered
# 15     280          UPI      Pending
# 16     180         Card    Delivered
# 17     240         Cash    Delivered
# 18     230          UPI    Cancelled
# 19     160         Card      Pending
# 20     270         Cash    Delivered
# 21     340          UPI    Delivered
# 22     130         Card    Cancelled
# 23     190         Cash      Pending
# 24     290          UPI    Delivered
# 25     200         Card    Delivered
# 26     150         Cash      Pending
# 27     310          UPI    Delivered
# 28     140         Card    Cancelled
# 29     220         Cash    Delivered
# 30     250          UPI      Pending
# 31     170         Card    Delivered
# 32     120         Cash    Cancelled
# 33     320          UPI    Delivered
# 34     180         Card    Delivered
# 35     190         Cash      Pending
# 36     280          UPI    Cancelled
# 37     150         Card    Delivered
# 38     230         Cash      Pending
# 39     260          UPI    Delivered
# 40     140         Card    Delivered
# 41     240         Cash    Cancelled
# 42     290          UPI      Pending
# 43     160         Card    Delivered
# 44     210         Cash    Delivered
# 45     300          UPI      Pending
# 46     180         Card    Cancelled
# 47     270         Cash    Delivered
# 48     150          UPI      Pending
# 49     220         Card    Delivered

# %%
df.groupby("City")["Sales"].sum().reset_index()
# Out:
#      City  Sales
# 0   Delhi  16350
# 1  Jaipur   9630
# 2  Mumbai  17000
# 3    Pune  10230

# %%
df.groupby("Category")["Sales"].mean().reset_index()
# Out:
#       Category        Sales
# 0     Clothing   795.294118
# 1  Electronics  1362.352941
# 2    Furniture  1033.125000

# %%
df.groupby("Category")["Profit"].sum().reset_index()
# Out:
#       Category  Profit
# 0     Clothing    2730
# 1  Electronics    4590
# 2    Furniture    3250

# %%
df.groupby("Product")["Quantity"].sum().reset_index()
# Out:
#        Product  Quantity
# 0        Chair         9
# 1         Desk         6
# 2   Headphones         8
# 3       Jacket        11
# 4        Jeans        11
# 5       Laptop        11
# 6       Mobile         9
# 7        Shoes        25
# 8         Sofa         8
# 9      T-Shirt        15
# 10       Table         8
# 11      Tablet        11

# %%
df.groupby("City")["Order_Status"].count().reset_index()
# Out:
#      City  Order_Status
# 0   Delhi            15
# 1  Jaipur            10
# 2  Mumbai            15
# 3    Pune            10

# %%
df.groupby("City")["Sales"].max().reset_index()
# Out:
#      City  Sales
# 0   Delhi   1600
# 1  Jaipur   1450
# 2  Mumbai   1700
# 3    Pune   1450

# %%
df.groupby("Category")["Profit"].min().reset_index()
# Out:
#       Category  Profit
# 0     Clothing     130
# 1  Electronics     150
# 2    Furniture     120

# %%
df.groupby("Payment_Mode")["Quantity"].mean().reset_index()
# Out:
#   Payment_Mode  Quantity
# 0         Card     3.000
# 1         Cash     1.875
# 2          UPI     3.000

# %%
df.groupby("Category")["Sales"].agg({"sum","mean","min","max"}).reset_index()
# Out:
#       Category   max  min         mean    sum
# 0     Clothing  1100  600   795.294118  13520
# 1  Electronics  1700  760  1362.352941  23160
# 2    Furniture  1350  600  1033.125000  16530

# %%
df.groupby("City")[["Sales","Profit"]].sum().reset_index()
# Out:
#      City  Sales  Profit
# 0   Delhi  16350    3230
# 1  Jaipur   9630    1950
# 2  Mumbai  17000    3360
# 3    Pune  10230    2030

# %%
df.groupby("Category")["Quantity"].agg({"sum","mean"}).reset_index()
# Out:
#       Category      mean  sum
# 0     Clothing  3.294118   56
# 1  Electronics  3.000000   51
# 2    Furniture  1.562500   25

# %%
df.groupby("Category")["Quantity"].agg({"sum","mean"})
# Out:
#                  mean  sum
# Category
# Clothing     3.294118   56
# Electronics  3.000000   51
# Furniture    1.562500   25

# %%
df.groupby("City")[["Sales","Profit"]].agg({"sum","mean"}).reset_index()
# Out:
#      City        Sales             Profit
#                   mean    sum        mean   sum
# 0   Delhi  1090.000000  16350  215.333333  3230
# 1  Jaipur   963.000000   9630  195.000000  1950
# 2  Mumbai  1133.333333  17000  224.000000  3360
# 3    Pune  1023.000000  10230  203.000000  2030

# %%
df.groupby(["City","Category"])["Sales"].sum().reset_index()
# Out:
#       City     Category  Sales
# 0    Delhi     Clothing   4400
# 1    Delhi  Electronics   7100
# 2    Delhi    Furniture   4850
# 3   Jaipur     Clothing   3050
# 4   Jaipur  Electronics   5200
# 5   Jaipur    Furniture   1380
# 6   Mumbai     Clothing   4450
# 7   Mumbai  Electronics   7500
# 8   Mumbai    Furniture   5050
# 9     Pune     Clothing   1620
# 10    Pune  Electronics   3360
# 11    Pune    Furniture   5250

# %%
df.groupby(["City","Payment_Mode"])["Profit"].sum().reset_index()
# Out:
#       City Payment_Mode  Profit
# 0    Delhi         Card     880
# 1    Delhi         Cash     970
# 2    Delhi          UPI    1380
# 3   Jaipur         Card     490
# 4   Jaipur         Cash     420
# 5   Jaipur          UPI    1040
# 6   Mumbai         Card     870
# 7   Mumbai         Cash     990
# 8   Mumbai          UPI    1500
# 9     Pune         Card     500
# 10    Pune         Cash     860
# 11    Pune          UPI     670

# %%
df.groupby(["Category","Payment_Mode"])["Sales"].mean().reset_index()
# Out:
#       Category Payment_Mode        Sales
# 0     Clothing         Card   814.666667
# 1     Clothing         Cash   650.000000
# 2  Electronics          UPI  1362.352941
# 3    Furniture         Card   850.000000
# 4    Furniture         Cash  1059.285714

# %%
df.groupby(["City","Category"])["Profit"].sum().reset_index()
# Out:
#       City     Category  Profit
# 0    Delhi     Clothing     880
# 1    Delhi  Electronics    1380
# 2    Delhi    Furniture     970
# 3   Jaipur     Clothing     640
# 4   Jaipur  Electronics    1040
# 5   Jaipur    Furniture     270
# 6   Mumbai     Clothing     890
# 7   Mumbai  Electronics    1500
# 8   Mumbai    Furniture     970
# 9     Pune     Clothing     320
# 10    Pune  Electronics     670
# 11    Pune    Furniture    1040

# %%
df.groupby(["City","Category"])["Profit"].max().reset_index()
# Out:
#       City     Category  Profit
# 0    Delhi     Clothing     160
# 1    Delhi  Electronics     320
# 2    Delhi    Furniture     270
# 3   Jaipur     Clothing     180
# 4   Jaipur  Electronics     290
# 5   Jaipur    Furniture     150
# 6   Mumbai     Clothing     220
# 7   Mumbai  Electronics     340
# 8   Mumbai    Furniture     240
# 9     Pune     Clothing     180
# 10    Pune  Electronics     290
# 11    Pune    Furniture     250

# %%
df.groupby("Payment_Mode").agg(
    total_sales = ("Sales","sum"),
    average_sales = ("Sales","mean"),
    total_profit = ("Profit","sum"),
    number_orders = ("Order_Status","count")
).round(2)
# Out:
#               total_sales  average_sales  total_profit  number_orders
# Payment_Mode
# Card                13920         818.82          2740             17
# Cash                16130        1008.12          3240             16
# UPI                 23160        1362.35          4590             17

# %%
data = {
    'Order_ID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210,
                 211, 212, 213, 214, 215],

    'Region': ['North', 'South', 'East', 'West', 'North',
               'South', 'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South', 'East'],

    'Product': ['Laptop', 'Mobile', 'Tablet', 'Laptop', 'Mobile',
                'Tablet', 'Laptop', 'Mobile', 'Tablet', 'Laptop',
                'Mobile', 'Tablet', 'Laptop', 'Mobile', 'Tablet'],

    'Salesperson': ['Raj', 'Priya', 'Aman', 'Neha', 'Raj',
                    'Priya', 'Aman', 'Neha', 'Raj', 'Priya',
                    'Aman', 'Neha', 'Raj', 'Priya', 'Aman'],

    'Sales': [55000, 30000, 22000, 48000, 35000,
              25000, 60000, 28000, 24000, 52000,
              33000, 27000, 65000, 31000, 21000],

    'Quantity': [2, 3, 2, 1, 4,
                 3, 2, 2, 3, 1,
                 5, 2, 2, 4, 3]
}

df = pd.DataFrame(data)

df
# Out:
#     Order_ID Region Product Salesperson  Sales  Quantity
# 0        201  North  Laptop         Raj  55000         2
# 1        202  South  Mobile       Priya  30000         3
# 2        203   East  Tablet        Aman  22000         2
# 3        204   West  Laptop        Neha  48000         1
# 4        205  North  Mobile         Raj  35000         4
# 5        206  South  Tablet       Priya  25000         3
# 6        207   East  Laptop        Aman  60000         2
# 7        208   West  Mobile        Neha  28000         2
# 8        209  North  Tablet         Raj  24000         3
# 9        210  South  Laptop       Priya  52000         1
# 10       211   East  Mobile        Aman  33000         5
# 11       212   West  Tablet        Neha  27000         2
# 12       213  North  Laptop         Raj  65000         2
# 13       214  South  Mobile       Priya  31000         4
# 14       215   East  Tablet        Aman  21000         3

# %%
pd.pivot_table(
    df,
    values = "Sales",
    index = "Region",
    aggfunc = "sum"
)
# Out:
#          Sales
# Region
# East    136000
# North   179000
# South   138000
# West    103000

# %%
pd.pivot_table(
    df,
    values = "Sales",
    index = "Region",
    aggfunc = "mean"
)
# Out:
#                Sales
# Region
# East    34000.000000
# North   44750.000000
# South   34500.000000
# West    34333.333333

# %%
pd.pivot_table(
    df,
    index = "Salesperson",
    columns = "Product",
    aggfunc = "sum"
)
# Out:
#             Order_ID               Quantity                    Region  \
# Product       Laptop Mobile Tablet   Laptop Mobile Tablet      Laptop
# Salesperson
# Aman             207    211    418        2      5      5        East
# Neha             204    208    212        1      2      2        West
# Priya            210    416    206        1      7      3       South
# Raj              414    205    209        4      4      3  NorthNorth
#
#                                     Sales
# Product          Mobile    Tablet  Laptop Mobile Tablet
# Salesperson
# Aman               East  EastEast   60000  33000  43000
# Neha               West      West   48000  28000  27000
# Priya        SouthSouth     South   52000  61000  25000
# Raj               North     North  120000  35000  24000

# %%
pd.pivot_table(
    df,
    values = "Sales",
    index = "Salesperson",
    columns = "Region",
    aggfunc = "sum"
)
# Out:
# Region           East     North     South      West
# Salesperson
# Aman         136000.0       NaN       NaN       NaN
# Neha              NaN       NaN       NaN  103000.0
# Priya             NaN       NaN  138000.0       NaN
# Raj               NaN  179000.0       NaN       NaN
