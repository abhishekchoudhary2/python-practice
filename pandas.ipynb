# %%
import numpy as np

# %%
import pandas as pd

# %%
data=np.array(['g','f','e','f','k','l','k'])
print(data)
print(type(data))
# Out:
# ['g' 'f' 'e' 'f' 'k' 'l' 'k']
# <class 'numpy.ndarray'>

# %%
s=pd.Series(data)
print("pandas Series",s)
print(type(s))
# Out:
# pandas Series 0    g
# 1    f
# 2    e
# 3    f
# 4    k
# 5    l
# 6    k
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
a=[2,3,43,4,54,8]
print(a)
# Out:
# [2, 3, 43, 4, 54, 8]

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(a)
print(df)
# Out:
#     0
# 0   2
# 1   3
# 2  43
# 3   4
# 4  54
# 5   8

# %%
d={
    "name":["abhishek","riya"],
    "age":[21,23],
    "city":["jaipur","delhi"]
}
df = pd.DataFrame(d)
df
# Out:
#        name  age    city
# 0  abhishek   21  jaipur
# 1      riya   23   delhi

# %%
d={
    "name":["abhishek","riya"],
    "age":[21,23],
    "city":["jaipur","delhi"]
}
df = pd.DataFrame(d)
df
# df.to_csv("bans.csv")
df
df.to_csv("bans.csv",index=False)
df
# Out:
#        name  age    city
# 0  abhishek   21  jaipur
# 1      riya   23   delhi
