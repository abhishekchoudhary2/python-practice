# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("amazon.csv")
print(df)
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 0       U356787     P39256  Electronics      Mobile      H&M  33090.51
# 1       U198246     P38657       Sports     Outdoor  Samsung   9368.97
# 2       U539898     P38893       Sports     Fitness      H&M  14756.85
# 3       U325772     P54118       Beauty      Makeup     Sony    668.83
# 4       U865179     P70217         Home       Decor     Sony  10881.29
# ...         ...        ...          ...         ...      ...       ...
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 0          10.46     29629.31     4.9            43     71     S2679
# 1           5.32      8870.73     3.9            13    119     S9279
# 2          26.00     10919.43     4.2            46    229     S5557
# 3          24.81       502.91     3.8             6     52     S2519
# 4          48.63      5589.58     4.0            48    274     S3045
# ...          ...          ...     ...           ...    ...       ...
# 999995     36.55       938.34     4.1            15    392     S7795
# 999996      5.22      4295.44     4.2            32     17     S4919
# 999997     29.00     10640.50     4.5           115    382     S4196
# 999998     21.43      3514.86     4.2            14    451     S3812
# 999999      8.25     65480.69     5.0            36    109     S1286
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 0                 4.3    2025-03-04                   6  Bangalore
# 1                 4.9    2025-12-12                   1      Delhi
# 2                 4.9    2024-04-25                   1    Chennai
# 3                 3.1    2025-12-18                   2     Mumbai
# 4                 2.6    2024-05-16                   5      Delhi
# ...               ...           ...                 ...        ...
# 999995            4.2    2025-03-12                   1      Delhi
# 999996            3.6    2025-11-04                   5  Hyderabad
# 999997            2.8    2025-11-06                   5  Hyderabad
# 999998            2.9    2025-02-25                   1      Delhi
# 999999            2.8    2025-05-28                   5    Chennai
#
#             device payment_method  is_returned delivery_status
# 0           Tablet            UPI         True        Returned
# 1           Tablet            UPI         True        Returned
# 2       Mobile App    Credit Card         True        Returned
# 3              Web            UPI        False      In Transit
# 4              Web            UPI        False         Delayed
# ...            ...            ...          ...             ...
# 999995  Mobile App    Credit Card        False       Delivered
# 999996  Mobile App     Debit Card        False      In Transit
# 999997         Web     Debit Card        False      In Transit
# 999998      Tablet     Debit Card        False       Delivered
# 999999  Mobile App            UPI        False         Delayed
#
# [1000000 rows x 20 columns]

# %%
print(df.head())
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
#
#    final_price  rating  review_count  stock seller_id  seller_rating  \
# 0     29629.31     4.9            43     71     S2679            4.3
# 1      8870.73     3.9            13    119     S9279            4.9
# 2     10919.43     4.2            46    229     S5557            4.9
# 3       502.91     3.8             6     52     S2519            3.1
# 4      5589.58     4.0            48    274     S3045            2.6
#
#   purchase_date  shipping_time_days   location      device payment_method  \
# 0    2025-03-04                   6  Bangalore      Tablet            UPI
# 1    2025-12-12                   1      Delhi      Tablet            UPI
# 2    2024-04-25                   1    Chennai  Mobile App    Credit Card
# 3    2025-12-18                   2     Mumbai         Web            UPI
# 4    2024-05-16                   5      Delhi         Web            UPI
#
#    is_returned delivery_status
# 0         True        Returned
# 1         True        Returned
# 2         True        Returned
# 3        False      In Transit
# 4        False         Delayed

# %%
print(df.tail())
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 999995     36.55       938.34     4.1            15    392     S7795
# 999996      5.22      4295.44     4.2            32     17     S4919
# 999997     29.00     10640.50     4.5           115    382     S4196
# 999998     21.43      3514.86     4.2            14    451     S3812
# 999999      8.25     65480.69     5.0            36    109     S1286
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 999995            4.2    2025-03-12                   1      Delhi
# 999996            3.6    2025-11-04                   5  Hyderabad
# 999997            2.8    2025-11-06                   5  Hyderabad
# 999998            2.9    2025-02-25                   1      Delhi
# 999999            2.8    2025-05-28                   5    Chennai
#
#             device payment_method  is_returned delivery_status
# 999995  Mobile App    Credit Card        False       Delivered
# 999996  Mobile App     Debit Card        False      In Transit
# 999997         Web     Debit Card        False      In Transit
# 999998      Tablet     Debit Card        False       Delivered
# 999999  Mobile App            UPI        False         Delayed

# %%
print(df.sample(10))
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 689900  U645123     P90191       Sports     Cycling       HP   5485.50
# 539045  U896197     P77919         Home       Decor   Lenovo   3825.16
# 737929  U705383     P84250  Electronics      Laptop   Lenovo  29952.52
# 517618  U848054     P58701         Home   Furniture     Sony  14703.34
# 944282  U646409     P99777         Home     Kitchen     Boat  18742.80
# 558573  U186276     P83953       Beauty      Makeup       HP    857.13
# 418168  U553592     P88979       Beauty    Skincare     Boat   2819.62
# 285369  U960096     P73294       Beauty    Skincare    Apple    549.19
# 15741   U865702     P53722         Home     Kitchen     Zara   7071.16
# 737384  U171687     P67726  Electronics      Laptop  Samsung  71661.99
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 689900     35.62      3531.83     3.6            23    326     S3403
# 539045     29.83      2684.09     4.2            67    225     S9145
# 737929     17.08     24835.53     3.8            24    247     S2540
# 517618      7.08     13662.60     3.5            16    169     S8512
# 944282     15.92     15759.06     4.5             5      0     S3140
# 558573     14.39       733.76     3.0            19    312     S4160
# 418168     25.94      2088.27     3.8             5    208     S1107
# 285369     13.49       475.09     4.3             7    338     S7080
# 15741      30.62      4906.15     4.5            65    214     S3609
# 737384     28.43     51291.75     5.0            27    445     S6476
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 689900            4.6    2025-11-14                   2  Hyderabad
# 539045            3.6    2024-10-02                   1  Bangalore
# 737929            4.0    2025-10-12                   1      Delhi
# 517618            4.2    2024-06-21                   5     Mumbai
# 944282            3.4    2025-02-10                   3    Chennai
# 558573            2.9    2025-03-08                   4  Hyderabad
# 418168            4.7    2025-07-19                   5     Mumbai
# 285369            4.3    2025-07-22                   3      Delhi
# 15741             2.6    2024-05-12                   5    Chennai
# 737384            3.9    2024-05-06                   1     Mumbai
#
#             device    payment_method  is_returned delivery_status
# 689900      Tablet               UPI        False         Delayed
# 539045  Mobile App               UPI        False       Delivered
# 737929  Mobile App               UPI         True        Returned
# 517618      Tablet       Credit Card        False      In Transit
# 944282  Mobile App  Cash on Delivery        False         Delayed
# 558573         Web        Debit Card        False       Delivered
# 418168      Tablet  Cash on Delivery         True        Returned
# 285369         Web        Debit Card        False      In Transit
# 15741       Tablet               UPI         True        Returned
# 737384      Tablet       Credit Card        False       Delivered

# %%
print(df.shape)
# Out:
# (1000000, 20)

# %%
print(df.dtypes)
# Out:
# user_id                object
# product_id             object
# category               object
# subcategory            object
# brand                  object
# price                 float64
# discount              float64
# final_price           float64
# rating                float64
# review_count            int64
# stock                   int64
# seller_id              object
# seller_rating         float64
# purchase_date          object
# shipping_time_days      int64
# location               object
# device                 object
# payment_method         object
# is_returned              bool
# delivery_status        object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['user_id', 'product_id', 'category', 'subcategory', 'brand', 'price',
#        'discount', 'final_price', 'rating', 'review_count', 'stock',
#        'seller_id', 'seller_rating', 'purchase_date', 'shipping_time_days',
#        'location', 'device', 'payment_method', 'is_returned',
#        'delivery_status'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['user_id', 'product_id', 'category', 'subcategory', 'brand', 'price', 'discount', 'final_price', 'rating', 'review_count', 'stock', 'seller_id', 'seller_rating', 'purchase_date', 'shipping_time_days', 'location', 'device', 'payment_method', 'is_returned', 'delivery_status']

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   user_id             1000000 non-null  object
#  1   product_id          1000000 non-null  object
#  2   category            1000000 non-null  object
#  3   subcategory         1000000 non-null  object
#  4   brand               1000000 non-null  object
#  5   price               1000000 non-null  float64
#  6   discount            1000000 non-null  float64
#  7   final_price         1000000 non-null  float64
#  8   rating              1000000 non-null  float64
#  9   review_count        1000000 non-null  int64
#  10  stock               1000000 non-null  int64
#  11  seller_id           1000000 non-null  object
#  12  seller_rating       1000000 non-null  float64
#  13  purchase_date       1000000 non-null  object
#  14  shipping_time_days  1000000 non-null  int64
#  15  location            1000000 non-null  object
#  16  device              1000000 non-null  object
#  17  payment_method      1000000 non-null  object
#  18  is_returned         1000000 non-null  bool
#  19  delivery_status     1000000 non-null  object
# dtypes: bool(1), float64(5), int64(3), object(11)
# memory usage: 145.9+ MB
# None

# %%
print(df.empty)
# Out:
# False

# %%
print(df.describe())
# Out:
#                 price        discount     final_price          rating  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean     13224.119093       28.996161     9938.876985        3.927226
# std      18079.626921       14.681077    14271.885557        0.519443
# min        200.030000        5.000000      101.460000        1.500000
# 25%       2700.147500       16.910000     1705.930000        3.600000
# 50%       4971.830000       28.070000     3790.795000        3.900000
# 75%      14134.482500       39.240000    10384.440000        4.300000
# max      79999.700000       70.000000    75831.110000        5.000000
#
#          review_count           stock   seller_rating  shipping_time_days
# count  1000000.000000  1000000.000000  1000000.000000      1000000.000000
# mean        32.626704      250.023345        3.750030            3.166389
# std         43.382201      144.567038        0.722092            1.674178
# min          0.000000        0.000000        2.500000            1.000000
# 25%         10.000000      125.000000        3.100000            2.000000
# 50%         20.000000      250.000000        3.800000            3.000000
# 75%         39.000000      375.000000        4.400000            5.000000
# max       3408.000000      500.000000        5.000000            6.000000

# %%
print(df.describe(include="all"))
# Out:
#         user_id product_id category subcategory    brand           price  \
# count   1000000    1000000  1000000     1000000  1000000  1000000.000000
# unique   603815      89999        5          16       12             NaN
# top     U678771     P96731     Home       Decor       LG             NaN
# freq          9         28   200922       67260    83882             NaN
# mean        NaN        NaN      NaN         NaN      NaN    13224.119093
# std         NaN        NaN      NaN         NaN      NaN    18079.626921
# min         NaN        NaN      NaN         NaN      NaN      200.030000
# 25%         NaN        NaN      NaN         NaN      NaN     2700.147500
# 50%         NaN        NaN      NaN         NaN      NaN     4971.830000
# 75%         NaN        NaN      NaN         NaN      NaN    14134.482500
# max         NaN        NaN      NaN         NaN      NaN    79999.700000
#
#               discount     final_price          rating    review_count  \
# count   1000000.000000  1000000.000000  1000000.000000  1000000.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean         28.996161     9938.876985        3.927226       32.626704
# std          14.681077    14271.885557        0.519443       43.382201
# min           5.000000      101.460000        1.500000        0.000000
# 25%          16.910000     1705.930000        3.600000       10.000000
# 50%          28.070000     3790.795000        3.900000       20.000000
# 75%          39.240000    10384.440000        4.300000       39.000000
# max          70.000000    75831.110000        5.000000     3408.000000
#
#                  stock seller_id   seller_rating purchase_date  \
# count   1000000.000000   1000000  1000000.000000       1000000
# unique             NaN      9000             NaN           731
# top                NaN     S9155             NaN    2025-01-13
# freq               NaN       156             NaN          1494
# mean        250.023345       NaN        3.750030           NaN
# std         144.567038       NaN        0.722092           NaN
# min           0.000000       NaN        2.500000           NaN
# 25%         125.000000       NaN        3.100000           NaN
# 50%         250.000000       NaN        3.800000           NaN
# 75%         375.000000       NaN        4.400000           NaN
# max         500.000000       NaN        5.000000           NaN
#
#         shipping_time_days location      device    payment_method is_returned  \
# count       1000000.000000  1000000     1000000           1000000     1000000
# unique                 NaN        5           3                 4           2
# top                    NaN    Delhi  Mobile App  Cash on Delivery       False
# freq                   NaN   200649      333637            250388      884010
# mean              3.166389      NaN         NaN               NaN         NaN
# std               1.674178      NaN         NaN               NaN         NaN
# min               1.000000      NaN         NaN               NaN         NaN
# 25%               2.000000      NaN         NaN               NaN         NaN
# 50%               3.000000      NaN         NaN               NaN         NaN
# 75%               5.000000      NaN         NaN               NaN         NaN
# max               6.000000      NaN         NaN               NaN         NaN
#
#        delivery_status
# count          1000000
# unique               4
# top          Delivered
# freq            295234
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("amazon.csv")

# %%
print(df["user_id"].nunique())
# Out:
# 603815
