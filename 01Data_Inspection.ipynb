# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('../Data/Raw_Data/airbnb_dataset.csv')

# %%
df.shape
# Out:
# (20120, 27)

# %%
df.columns
# Out:
# Index(['listing_id', 'host_id', 'host_name', 'neighbourhood', 'city',
#        'room_type', 'property_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month', 'availability_365',
#        'latitude', 'longitude', 'host_since', 'last_review', 'rating', 'beds',
#        'bedrooms', 'bathrooms', 'guests', 'instant_bookable',
#        'cancellation_policy', 'host_response_rate', 'listing_status', 'device',
#        'payment_method'],
#       dtype='str')

# %%
df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276       NaN          Bronx  New York City
# 1      109454     5049      Emma     Manhattan             NYC
# 2      119857    11567    Sophia     Manhattan             NYC
# 3      108591     5546       NaN         Queens            NYC
# 4      117164     8693   Michael  Staten Island       New York
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       Hotel room     apartment  213.62              27                 51
# 1     Private Room   Guest suite     289              15                 38
# 2     Private room           NaN  130.82              24                 39
# 3  Entire home/apt     Apartment   36.43              13                 49
# 4  entire home/apt          Loft  271.74              21                 41
#
#    ...  beds  bedrooms  bathrooms  guests instant_bookable  \
# 0  ...   NaN      -1.0     1 bath     8.0                T
# ...

# %%
df.tail()
# Out:
#        listing_id  host_id   host_name  neighbourhood       city  \
# 20115      111285    11257      Sophia       Brooklyn   New York
# 20116      111965     8929       David          Bronx  New York
# 20117      105391    10739     Michael  Staten Island  New York
# 20118      100861     8325  John Smith       Brooklyn        NYC
# 20119      115796     5659         NaN         Queens        NYC
#
#              room_type property_type   price  minimum_nights  \
# 20115      Shared room     Townhouse   68.76             365
# 20116     Private Room   Guest suite   69.01              19
# 20117  entire home/apt     apartment  280.07              12
# 20118      Shared room           NaN  476.49             365
# 20119     Private Room     Townhouse   84.16            3650
#
#        number_of_reviews  ...  beds  bedrooms  bathrooms  guests  \
# 20115                 44  ...   1.0       1.0    3 baths     1.0
# 20116                 30  ...   NaN       5.0     1 bath     6.0
# ...

# %%
df.dtypes
# Out:
# listing_id               int64
# host_id                  int64
# host_name                  str
# neighbourhood              str
# city                       str
# room_type                  str
# property_type              str
# price                      str
# minimum_nights           int64
# number_of_reviews        int64
# reviews_per_month      float64
# availability_365         int64
# latitude               float64
# longitude              float64
# host_since                 str
# last_review                str
# rating                 float64
# beds                   float64
# bedrooms               float64
# bathrooms                  str
# guests                 float64
# instant_bookable           str
# cancellation_policy        str
# host_response_rate         str
# listing_status             str
# device                     str
# payment_method             str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20120 entries, 0 to 20119
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           20120 non-null  int64
#  1   host_id              20120 non-null  int64
#  2   host_name            16495 non-null  str
#  3   neighbourhood        20120 non-null  str
#  4   city                 20120 non-null  str
#  5   room_type            20120 non-null  str
#  6   property_type        17838 non-null  str
#  7   price                19637 non-null  str
#  8   minimum_nights       20120 non-null  int64
#  9   number_of_reviews    20120 non-null  int64
#  10  reviews_per_month    18509 non-null  float64
#  11  availability_365     20120 non-null  int64
#  12  latitude             20120 non-null  float64
#  13  longitude            20120 non-null  float64
#  14  host_since           20120 non-null  str
#  15  last_review          18105 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# listing_id                0
# host_id                   0
# host_name              3625
# neighbourhood             0
# city                      0
# room_type                 0
# property_type          2282
# price                   483
# minimum_nights            0
# number_of_reviews         0
# reviews_per_month      1611
# availability_365          0
# latitude                  0
# longitude                 0
# host_since                0
# last_review            2015
# rating                 1007
# beds                   1648
# bedrooms               3419
# bathrooms              2303
# guests                 2747
# instant_bookable       2915
# cancellation_policy       0
# host_response_rate     3331
# listing_status         3284
# device                 3344
# payment_method         3383
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(120)

# %%
df.nunique()
# Out:
# listing_id             20000
# host_id                 6590
# host_name                  6
# neighbourhood              9
# city                       4
# room_type                  7
# property_type              8
# price                  14115
# minimum_nights            36
# number_of_reviews         52
# reviews_per_month        837
# availability_365         366
# latitude               18982
# longitude              19125
# host_since              3868
# last_review             3859
# rating                   217
# beds                      11
# bedrooms                   8
# bathrooms                  8
# guests                     9
# instant_bookable           6
# cancellation_policy        6
# host_response_rate         5
# listing_status             5
# device                     5
# payment_method             5
# dtype: int64

# %%
df.describe()
# Out:
#           listing_id       host_id  minimum_nights  number_of_reviews  \
# count   20120.000000  20120.000000    20120.000000       20120.000000
# mean   110000.369930   8487.921968      154.248260          45.038867
# std      5773.090391   2007.642717      595.946473           6.664779
# min    100001.000000   5002.000000        1.000000          17.000000
# 25%    104993.750000   6753.750000       10.000000          40.000000
# 50%    110000.500000   8485.000000       18.000000          45.000000
# 75%    115001.250000  10227.250000       27.000000          49.000000
# max    120000.000000  11999.000000     3650.000000          71.000000
#
#        reviews_per_month  availability_365      latitude     longitude  \
# count       18509.000000       20120.00000  20120.000000  20120.000000
# mean            2.042103         183.01829     40.612102    -73.910002
# std             1.559679         105.52314      3.792597      5.926442
# ...

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['listing_id', 'host_id', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'availability_365', 'latitude', 'longitude',
#        'rating', 'beds', 'bedrooms', 'guests'],
#       dtype='str')

# %%
print(df['host_since'].head())
# Out:
# 0    2022-06-09
# 1    2017-07-20
# 2    2018-06-10
# 3    2020-02-23
# 4    2024-07-11
# Name: host_since, dtype: str

# %%
print(df['last_review'].head())
# Out:
# 0    2015-07-05
# 1           NaN
# 2    2023-06-02
# 3    2020-11-17
# 4    2023-12-02
# Name: last_review, dtype: str
