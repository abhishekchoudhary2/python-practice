# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("Netflix_data.csv")

# %%
print(df.head())
# Out:
#   show_id     type               title                       director  \
# 0  s10651    Movie  Garfield Gets Real  Mark A.Z. Dippé, Kyung Ho Lee
# 1   s2042    Movie         Sky on Fire                      Ringo Lam
# 2   s8669    Movie          Alien Xmas                 Stephen Chiodo
# 3   s1115    Movie            Arthur                              NaN
# 4  s13903  TV Show                GLOW                            NaN
#
#                                                 cast           country  \
# 0  Frank Welker, Wally Wingert, Gregg Berger, Jen...     United States
# 1  Daniel Wu, Joseph Chang, Amber Kuo, Zhang Jing...  China, Hong Kong
# 2  Keythe Farley, Dee Bradley Baker, Kaliayh Rham...     United States
# 3                                                NaN     United States
# 4  Alison Brie, Betty Gilpin, Marc Maron, Britney...     United States
#
#           date_added  release_year rating   duration
# 0    January 1, 2020        2007.0   TV-Y     78 min
# ...

# %%
print(df.tail())
# Out:
#       show_id     type                          title         director  \
# 19995  s11285    Movie            Muppets Most Wanted              NaN
# 19996  s11965    Movie    R.L. Stine's Mostly Ghostly  Richard Correll
# 19997   s5391  TV Show                          Vexed              NaN
# 19998    s861    Movie  Chhota Bheem: Bheem vs Aliens    Rajiv Chilaka
# 19999  s15796    Movie             Lying and Stealing     Matt Aselton
#
#                                                     cast         country  \
# 19995  Ricky Gervais, Ty Burrell, Tina Fey, Kermit th...   United States
# 19996  Madison Pettis, Sterling Beaumon, Luke Benward...   United States
# 19997  Toby Stephens, Miranda Raison, Lucy Punch, Nic...  United Kingdom
# 19998  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...             NaN
# 19999  Theo James, Emily Ratajkowski, Fred Melamed, E...   United States
#
#               date_added  release_year rating   duration
# ...

# %%
print(df.sample(10))
# Out:
#       show_id     type                                title          director  \
# 5289    s9086    Movie                             Euphoria    Valeria Golino
# 11502   s9374  TV Show                             Aquarius               NaN
# 665    s15993    Movie     Hannibal Buress: Comedy Camisado       Lance Bangs
# 15956   s2618    Movie                       Blue Valentine  Derek Cianfrance
# 14421  s15665    movie                               Inxeba     John Trengove
# 2145    s9730    Movie  Kevin Hart's Guide to Black History         Tom Stern
# 11689   s5560    Movie                         Alice Junior               NaN
# 9719    s9936  TV Show                    Kim's Convenience               NaN
# 10199  s10546    Movie                           Santa Girl     Blayne Weaver
# 3995    s4074    Movie               NOVA: Thai Cave Rescue  Tom Stubberfield
#
#                                                     cast  \
# ...

# %%
print(df.shape)
# Out:
# (20000, 10)

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       20000 non-null  object
#  1   type          20000 non-null  object
#  2   title         20000 non-null  object
#  3   director      12136 non-null  object
#  4   cast          15964 non-null  object
#  5   country       14570 non-null  object
#  6   date_added    16371 non-null  object
#  7   release_year  16745 non-null  float64
#  8   rating        16069 non-null  object
#  9   duration      16499 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.5+ MB
# None

# %%
print(df.describe())
# Out:
#        release_year
# count  16745.000000
# mean    2014.256972
# std        8.685029
# min     1925.000000
# 25%     2014.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
print(df.empty)
# Out:
# False

# %%
print(df["title"])
# Out:
# 0                   Garfield Gets Real
# 1                          Sky on Fire
# 2                           Alien Xmas
# 3                             Arthur
# 4                                 GLOW
#                      ...
# 19995              Muppets Most Wanted
# 19996      R.L. Stine's Mostly Ghostly
# 19997                            Vexed
# 19998    Chhota Bheem: Bheem vs Aliens
# 19999               Lying and Stealing
# Name: title, Length: 20000, dtype: object

# %%
print(df[["title","type"]])
# Out:
#                                title     type
# 0                 Garfield Gets Real    Movie
# 1                        Sky on Fire    Movie
# 2                         Alien Xmas    Movie
# 3                           Arthur      Movie
# 4                               GLOW  TV Show
# ...                              ...      ...
# 19995            Muppets Most Wanted    Movie
# 19996    R.L. Stine's Mostly Ghostly    Movie
# 19997                          Vexed  TV Show
# 19998  Chhota Bheem: Bheem vs Aliens    Movie
# 19999             Lying and Stealing    Movie
#
# [20000 rows x 2 columns]

# %%
print(df[["title","country","release_year","rating"]])
# Out:
#                                title           country  release_year rating
# 0                 Garfield Gets Real     United States        2007.0   TV-Y
# 1                        Sky on Fire  China, Hong Kong        2016.0  TV-MA
# 2                         Alien Xmas     United States        2020.0   TV-Y
# 3                           Arthur       United States        2011.0  PG-13
# 4                               GLOW     United States        2019.0    NaN
# ...                              ...               ...           ...    ...
# 19995            Muppets Most Wanted     United States        2014.0     PG
# 19996    R.L. Stine's Mostly Ghostly     United States        2008.0     PG
# 19997                          Vexed    United Kingdom           NaN    NaN
# 19998  Chhota Bheem: Bheem vs Aliens               NaN           NaN  TV-Y7
# 19999             Lying and Stealing     United States        2019.0    NaN
#
# [20000 rows x 4 columns]

# %%
print(df.head(20)[["title","director"]])
# Out:
#                                     title                       director
# 0                      Garfield Gets Real  Mark A.Z. Dippé, Kyung Ho Lee
# 1                             Sky on Fire                      Ringo Lam
# 2                              Alien Xmas                 Stephen Chiodo
# 3                                Arthur                              NaN
# 4                                    GLOW                            NaN
# 5                            I Heart Arlo                            NaN
# 6   Th Eena Meena Deeka Chase Comedy Show                  Dheeraj Berry
# 7                       The Vatican Tapes                 Mark Neveldine
# 8                          Whose Streets?    Sabaah Folayan, Damon Davis
# 9                              Khubsoorat           Hrishikesh Mukherjee
# 10                      See You Yesterday                 Stefon Bristol
# 11                     Beneath the Leaves                    Adam Marino
# ...

# %%
print(df[df["type"]=="Movie"])
# Out:
#       show_id   type                                              title  \
# 0      s10651  Movie                                 Garfield Gets Real
# 1       s2042  Movie                                        Sky on Fire
# 2       s8669  Movie                                         Alien Xmas
# 3       s1115  Movie                                           Arthur
# 7       s3003  Movie                                  The Vatican Tapes
# ...       ...    ...                                                ...
# 19989  s16024  Movie  GLOW: The Story of the Gorgeous Ladies of Wres...
# 19995  s11285  Movie                                Muppets Most Wanted
# 19996  s11965  Movie                        R.L. Stine's Mostly Ghostly
# 19998    s861  Movie                      Chhota Bheem: Bheem vs Aliens
# 19999  s15796  Movie                                 Lying and Stealing
#
#                             director  \
# 0      Mark A.Z. Dippé, Kyung Ho Lee
# ...

# %%
print(df[df["type"]=="TV Show"])
# Out:
#       show_id     type                                  title        director  \
# 4      s13903  TV Show                                   GLOW             NaN
# 5      s11964  TV Show                           I Heart Arlo             NaN
# 6      s11073  TV Show  Th Eena Meena Deeka Chase Comedy Show   Dheeraj Berry
# 15      s5253  TV Show                  The Haunted Hathaways             NaN
# 16       s311  TV Show                       12 Years Promise             NaN
# ...       ...      ...                                    ...             ...
# 19990  s11364  TV Show                 Merry Happy Whatever               NaN
# 19991  s14424  TV Show                      Hip-Hop Evolution             NaN
# 19993  s16851  TV Show                             Zero Chill             NaN
# 19994   s6266  TV Show                           The Twelve    Wouter Bouvijn
# 19997   s5391  TV Show                                  Vexed             NaN
#
# ...

# %%
print(df[(df["type"]=="Movie")&(df["release_year"]>2015)])
# Out:
#       show_id   type                                         title  \
# 1       s2042  Movie                                   Sky on Fire
# 2       s8669  Movie                                    Alien Xmas
# 8       s8558  Movie                                Whose Streets?
# 10      s3526  Movie                             See You Yesterday
# 11      s7880  Movie                            Beneath the Leaves
# ...       ...    ...                                           ...
# 19982   s6421  Movie  Tomasz Jachimek, Jacek Stramik Laugh at Live
# 19985   s2434  Movie                      Lucas Brothers: On Drugs
# 19986    s770  Movie                             The American Meme
# 19988   s8323  Movie                                  Mommy Issues
# 19999  s15796  Movie                            Lying and Stealing
#
#                           director  \
# 1                        Ringo Lam
# 2                   Stephen Chiodo
# 8      Sabaah Folayan, Damon Davis
# ...

# %%
print(df[df["release_year"] == 2020])
# Out:
#       show_id     type                                           title  \
# 2       s8669    Movie                                      Alien Xmas
# 12     s16442    Movie                                    Romance Doll
# 75      s1621    Movie                                        Wild Dog
# 78      s2784    Movie       Carmen Sandiego: To Steal or Not to Steal
# 114    s12345  TV Show                                  Brews Brothers
# ...       ...      ...                                             ...
# 19925   s7209  TV Show                                    Futmalls.com
# 19939   s6874    Movie  Wave of Cinema: One Day We'll Talk About Today
# 19943  s13418    Movie                         Hazel Brugger: Tropical
# 19972   s3006    movie                                        Deranged
# 19991  s14424  TV Show                               Hip-Hop Evolution
#
#               director                                               cast  \
# ...

# %%
print(df.loc[df["release_year"]==2020,"title"])
# Out:
# 2                                            Alien Xmas
# 12                                         Romance Doll
# 75                                             Wild Dog
# 78            Carmen Sandiego: To Steal or Not to Steal
# 114                                      Brews Brothers
#                               ...
# 19925                                      Futmalls.com
# 19939    Wave of Cinema: One Day We'll Talk About Today
# 19943                           Hazel Brugger: Tropical
# 19972                                          Deranged
# 19991                                 Hip-Hop Evolution
# Name: title, Length: 1794, dtype: object

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_data.csv")

# %%
print(df[df["country"]=="United States"])
# Out:
#       show_id     type                                              title  \
# 0      s10651    Movie                                 Garfield Gets Real
# 2       s8669    Movie                                         Alien Xmas
# 3       s1115    Movie                                           Arthur
# 4      s13903  TV Show                                               GLOW
# 7       s3003    Movie                                  The Vatican Tapes
# ...       ...      ...                                                ...
# 19989  s16024    Movie  GLOW: The Story of the Gorgeous Ladies of Wres...
# 19990  s11364  TV Show                             Merry Happy Whatever
# 19995  s11285    Movie                                Muppets Most Wanted
# 19996  s11965    Movie                        R.L. Stine's Mostly Ghostly
# 19999  s15796    Movie                                 Lying and Stealing
#
#                             director  \
# 0      Mark A.Z. Dippé, Kyung Ho Lee
# ...

# %%
print(df[(df["type"]=="Movie")&(df["rating"]=="TV-MA")])
# Out:
#       show_id   type                                         title  \
# 1       s2042  Movie                                   Sky on Fire
# 10      s3526  Movie                             See You Yesterday
# 11      s7880  Movie                            Beneath the Leaves
# 12     s16442  Movie                                  Romance Doll
# 13     s16297  Movie                                     The Mayor
# ...       ...    ...                                           ...
# 19969    s513  Movie                                     Deewangee
# 19982   s6421  Movie  Tomasz Jachimek, Jacek Stramik Laugh at Live
# 19985   s2434  Movie                      Lucas Brothers: On Drugs
# 19986    s770  Movie                             The American Meme
# 19987   s1686  Movie                          Simplemente Manu NNa
#
#                      director  \
# 1                   Ringo Lam
# 10             Stefon Bristol
# 11                Adam Marino
# 12                Yuki Tanada
# ...

# %%
print(df[(df["type"] == "Movie") & (df["release_year"]<2000)])
# Out:
#       show_id   type                          title              director  \
# 9       s8116  Movie                     Khubsoorat  Hrishikesh Mukherjee
# 42      s6518  Movie  Disciples Of The 36th Chamber                   NaN
# 49      s4059  Movie               Love on Delivery                   NaN
# 53     s13420  Movie                The Long Riders           Walter Hill
# 64      s7086  Movie                            FTA       Francine Parker
# ...       ...    ...                            ...                   ...
# 19824   s2328  Movie         A Night at the Roxbury      John Fortenberry
# 19870  s10922  Movie             Solo Con Tu Pareja        Alfonso Cuarón
# 19920   s8007  Movie                       The Game         David Fincher
# 19924   s5277  Movie      EVANGELION: DEATH (TRUE)²                   NaN
# 19963  s10628  Movie                   My Fair Lady          George Cukor
#
#                                                     cast        country  \
# ...

# %%
print(df[(df["type"]=="Movie")&(df["release_year"]>2011)])
# Out:
#       show_id   type                                              title  \
# 1       s2042  Movie                                        Sky on Fire
# 2       s8669  Movie                                         Alien Xmas
# 7       s3003  Movie                                  The Vatican Tapes
# 8       s8558  Movie                                     Whose Streets?
# 10      s3526  Movie                                  See You Yesterday
# ...       ...    ...                                                ...
# 19986    s770  Movie                                  The American Meme
# 19988   s8323  Movie                                       Mommy Issues
# 19989  s16024  Movie  GLOW: The Story of the Gorgeous Ladies of Wres...
# 19995  s11285  Movie                                Muppets Most Wanted
# 19999  s15796  Movie                                 Lying and Stealing
#
#                           director  \
# 1                        Ringo Lam
# ...
